# %% [markdown]
# what is text categorization? what are the type of text categorization?
#
# what is sentiment analysis?
#
# what are the type of sentiment analysis?
#
# what are some commercial use cases of text categorization?
#
# what is the task of language id?
#
# for what was the naive bayes invented? and when?
#
# what is the goal of classification?
#
# what is the most common way of doing text classification in language processing?
#
# what is supervised machine learning?
#
# what is a probabilistic classifier?
#
# what is a generative classifier?
#
# what is a discriminative classifier?
#
# what is the multinomial naive bayes classifier? what is the assumption that it makes?
#
# what type of classifier is the naive bayes?
#
# what is bag of words? how do you get it?
#
# what is the argmax operation?
#
# what is the idea behind Bayes inference?
#
# what is the assumption of how a document is generated when using the naive bayes?
#
# what are the prior probabiliity and the likelihood probability?
#
# what are the two simplifying assumptions that the naive bayes make when you cannot calculate the combinations of all the words?
#
# what is a feature in the naive bayes classifier for text classification?
#
# in what space are the naive bayes calculations done? and why? explain with an example. https://chatgpt.com/share/68767064-93b0-8006-b193-8e5a43a9a838
#
# what are linear classifiers?
#
# what is the problem with the naive bayes maximum likelihood training? how do you fix it?
#
# what do you do with unkwown words that are not in our vocabulary because they didn't occur in the training but occurred in the test?
#
# what do you usually do with stop words like "the", "a"?
#
# what is the binary multinoomial naive bayes or binary naive bayes?
#
# what is a common addition made when doing sentiment analysis for classification?
#
# what is sentiment lexicon? when do you use it? how do you use it?
#
# why does the naive bayes not require to use all the words in the training data as features? page 64
#
# how can the naive bayes be viewed when using all the words in the training in the context of language modelling?
#
# what are god labels?
#
# what is a confusion matrix?
#
# what is the equation for the *accuracy* and what does it ask? do you use accuracy for text classification? why?
#
# what is true positive, true negative, false positive and false negative?
#
# what is precision and recall?
#
# what is the F-measure?
#
# what data sets we use to train the model? what for tuning the parameters of the model?
#
# what problem does it create having a fixed training, dev and test set?
#
# how could we use all of our data for training and all of our dataset for testing too?
#
# what is the prblem with cross-validation? what is the requirement needed to use cross-validation?
#
# what is the model card? with what does it come?
